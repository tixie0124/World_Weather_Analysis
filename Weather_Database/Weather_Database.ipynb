# %%
#import the random modules
import random
#import the Numpy Module
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from citipy import citipy
import requests
from datetime import datetime

# %%
#generate 2000 random latitudes and longitudes and create a set of them
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)

# %%
#coordianates = latitues, longitudes, add them to the list
coordinates = list(lats_lngs)

# %%
#create a list to hold the cities
cities = []

#add city name to the cities list
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
#import the API key
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#create an empty list to hold the weather data
city_data = []
#Print the beginning of the logging
print("Beginning Data Retrival")
print("-----------------------------")

#create counters
record_count = 1
set_count = 1    

#loop through all the cities in our list

for i, city in enumerate(cities):
    

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrival
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | katsuura
# Processing Record 5 of Set 1 | leshukonskoye
# Processing Record 6 of Set 1 | port keats
# Processing Record 7 of Set 1 | lashio
# Processing Record 8 of Set 1 | jacareacanga
# Processing Record 9 of Set 1 | souillac
# Processing Record 10 of Set 1 | kaeo
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | gostyn
# Processing Record 13 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 1 | marsh harbour
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | kincardine
# Processing Record 17 of Set 1 | alice springs
# Processing Record 18 of Set 1 | matara
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | ilulissat
# Processing Record 25 of Set 1 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | kalispell
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | rocha
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | xadani
# City not found. Skipping...
# Processing Record 38 of Set 1 | vao
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | kingsport
# Processing Record 45 of Set 1 | montenegro
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | beeville
# Processing Record 48 of Set 1 | novonikolayevskiy
# Processing Record 49 of Set 1 | porto novo
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | plouzane
# Processing Record 2 of Set 2 | pahrump
# Processing Record 3 of Set 2 | grand gaube
# Processing Record 4 of Set 2 | sao filipe
# Processing Record 5 of Set 2 | salihli
# Processing Record 6 of Set 2 | isangel
# Processing Record 7 of Set 2 | guerrero negro
# Processing Record 8 of Set 2 | fort nelson
# Processing Record 9 of Set 2 | nelson bay
# Processing Record 10 of Set 2 | ciudad bolivar
# Processing Record 11 of Set 2 | emerald
# Processing Record 12 of Set 2 | brae
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | campbeltown
# Processing Record 16 of Set 2 | seoul
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | petropavlovka
# Processing Record 19 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 20 of Set 2 | shimoda
# Processing Record 21 of Set 2 | punta arenas
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | kahului
# Processing Record 24 of Set 2 | lavrentiya
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | gimli
# Processing Record 27 of Set 2 | rangpur
# Processing Record 28 of Set 2 | tygda
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | dwarka
# Processing Record 31 of Set 2 | akyab
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | novyy urengoy
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | mehamn
# Processing Record 39 of Set 2 | medicine hat
# Processing Record 40 of Set 2 | mpulungu
# Processing Record 41 of Set 2 | gbarnga
# Processing Record 42 of Set 2 | vila
# Processing Record 43 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | aklavik
# Processing Record 46 of Set 2 | kununurra
# Processing Record 47 of Set 2 | north platte
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | opobo
# City not found. Skipping...
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | port shepstone
# Processing Record 2 of Set 3 | airai
# Processing Record 3 of Set 3 | muros
# Processing Record 4 of Set 3 | bubaque
# Processing Record 5 of Set 3 | preobrazheniye
# Processing Record 6 of Set 3 | quzhou
# Processing Record 7 of Set 3 | glens falls
# Processing Record 8 of Set 3 | hovd
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | senador jose porfirio
# Processing Record 11 of Set 3 | berdigestyakh
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | paamiut
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | dobrinka
# Processing Record 16 of Set 3 | poum
# Processing Record 17 of Set 3 | bethel
# Processing Record 18 of Set 3 | wasilla
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 3 | hirekerur
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | tottori
# Processing Record 24 of Set 3 | tilichiki
# Processing Record 25 of Set 3 | port hedland
# Processing Record 26 of Set 3 | coquimbo
# Processing Record 27 of Set 3 | kloulklubed
# Processing Record 28 of Set 3 | hamilton
# Processing Record 29 of Set 3 | nabire
# Processing Record 30 of Set 3 | zhengjiatun
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | sistranda
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | sitka
# Processing Record 35 of Set 3 | tiarei
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | fortuna
# Processing Record 38 of Set 3 | tairua
# Processing Record 39 of Set 3 | valparaiso
# Processing Record 40 of Set 3 | coihaique
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | avera
# Processing Record 43 of Set 3 | tuensang
# Processing Record 44 of Set 3 | ancud
# Processing Record 45 of Set 3 | broken hill
# Processing Record 46 of Set 3 | ngunguru
# Processing Record 47 of Set 3 | hithadhoo
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | svetlaya
# Processing Record 50 of Set 3 | gualeguay
# Processing Record 1 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 4 | lodwar
# Processing Record 3 of Set 4 | pueblo nuevo
# Processing Record 4 of Set 4 | hilo
# Processing Record 5 of Set 4 | la ligua
# Processing Record 6 of Set 4 | praia da vitoria
# Processing Record 7 of Set 4 | narsaq
# Processing Record 8 of Set 4 | ziro
# Processing Record 9 of Set 4 | barra do corda
# Processing Record 10 of Set 4 | hofn
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | baker city
# Processing Record 13 of Set 4 | hoshcha
# Processing Record 14 of Set 4 | cayenne
# Processing Record 15 of Set 4 | binzhou
# Processing Record 16 of Set 4 | ariquemes
# Processing Record 17 of Set 4 | otane
# Processing Record 18 of Set 4 | mancio lima
# Processing Record 19 of Set 4 | atasu
# Processing Record 20 of Set 4 | wenling
# Processing Record 21 of Set 4 | poronaysk
# Processing Record 22 of Set 4 | shelburne
# Processing Record 23 of Set 4 | mbandaka
# Processing Record 24 of Set 4 | yuanping
# Processing Record 25 of Set 4 | mlalo
# Processing Record 26 of Set 4 | clearlake
# Processing Record 27 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 4 | panaba
# Processing Record 29 of Set 4 | sechura
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | agadez
# Processing Record 32 of Set 4 | dawei
# Processing Record 33 of Set 4 | haines junction
# Processing Record 34 of Set 4 | atuona
# Processing Record 35 of Set 4 | kirya
# Processing Record 36 of Set 4 | luderitz
# Processing Record 37 of Set 4 | derzhavinsk
# Processing Record 38 of Set 4 | ventspils
# Processing Record 39 of Set 4 | krasnokamensk
# Processing Record 40 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 4 | moose factory
# Processing Record 42 of Set 4 | georgetown
# Processing Record 43 of Set 4 | half moon bay
# Processing Record 44 of Set 4 | kovernino
# Processing Record 45 of Set 4 | topaipi
# Processing Record 46 of Set 4 | iqaluit
# Processing Record 47 of Set 4 | namibe
# Processing Record 48 of Set 4 | broome
# Processing Record 49 of Set 4 | sisimiut
# Processing Record 50 of Set 4 | tarauaca
# Processing Record 1 of Set 5 | angra
# City not found. Skipping...
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | port blair
# Processing Record 4 of Set 5 | pacific grove
# Processing Record 5 of Set 5 | sabha
# Processing Record 6 of Set 5 | fairbanks
# Processing Record 7 of Set 5 | saint-pacome
# City not found. Skipping...
# Processing Record 8 of Set 5 | ulaangom
# Processing Record 9 of Set 5 | hasaki
# Processing Record 10 of Set 5 | ho
# City not found. Skipping...
# Processing Record 11 of Set 5 | carnarvon
# Processing Record 12 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 5 | clyde river
# Processing Record 14 of Set 5 | antalaha
# Processing Record 15 of Set 5 | college
# Processing Record 16 of Set 5 | tucumcari
# Processing Record 17 of Set 5 | comodoro rivadavia
# Processing Record 18 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 5 | taoudenni
# Processing Record 20 of Set 5 | talnakh
# Processing Record 21 of Set 5 | saleilua
# City not found. Skipping...
# Processing Record 22 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | manali
# Processing Record 26 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 5 | lebu
# Processing Record 28 of Set 5 | dalvik
# Processing Record 29 of Set 5 | havelock
# Processing Record 30 of Set 5 | nanortalik
# Processing Record 31 of Set 5 | chernyshkovskiy
# Processing Record 32 of Set 5 | kisangani
# Processing Record 33 of Set 5 | kavieng
# Processing Record 34 of Set 5 | jonava
# Processing Record 35 of Set 5 | the pas
# Processing Record 36 of Set 5 | longyearbyen
# Processing Record 37 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 5 | yerbogachen
# Processing Record 39 of Set 5 | aykhal
# Processing Record 40 of Set 5 | kawalu
# Processing Record 41 of Set 5 | djenne
# Processing Record 42 of Set 5 | pangody
# Processing Record 43 of Set 5 | evansville
# Processing Record 44 of Set 5 | esperance
# Processing Record 45 of Set 5 | fayetteville
# Processing Record 46 of Set 5 | gazi
# Processing Record 47 of Set 5 | chapais
# Processing Record 48 of Set 5 | carutapera
# Processing Record 49 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 5 | thompson
# Processing Record 1 of Set 6 | lakatoro
# Processing Record 2 of Set 6 | leona vicario
# Processing Record 3 of Set 6 | kuito
# Processing Record 4 of Set 6 | ugoofaaru
# Processing Record 5 of Set 6 | san quintin
# Processing Record 6 of Set 6 | charyshskoye
# Processing Record 7 of Set 6 | touros
# Processing Record 8 of Set 6 | aginskoye
# Processing Record 9 of Set 6 | yankton
# Processing Record 10 of Set 6 | kemi
# Processing Record 11 of Set 6 | arraial do cabo
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | brenes
# Processing Record 14 of Set 6 | marzuq
# Processing Record 15 of Set 6 | khandyga
# Processing Record 16 of Set 6 | tamandare
# Processing Record 17 of Set 6 | calama
# Processing Record 18 of Set 6 | tabarqah
# City not found. Skipping...
# Processing Record 19 of Set 6 | tshikapa
# Processing Record 20 of Set 6 | lyaskelya
# Processing Record 21 of Set 6 | itupiranga
# Processing Record 22 of Set 6 | sumbe
# Processing Record 23 of Set 6 | alta floresta
# Processing Record 24 of Set 6 | pagudpud
# Processing Record 25 of Set 6 | vardo
# Processing Record 26 of Set 6 | reading
# Processing Record 27 of Set 6 | camacha
# Processing Record 28 of Set 6 | saskylakh
# Processing Record 29 of Set 6 | xining
# Processing Record 30 of Set 6 | taree
# Processing Record 31 of Set 6 | xai-xai
# Processing Record 32 of Set 6 | nannilam
# Processing Record 33 of Set 6 | provideniya
# Processing Record 34 of Set 6 | sobolevo
# Processing Record 35 of Set 6 | sibu
# Processing Record 36 of Set 6 | nantucket
# Processing Record 37 of Set 6 | casalmaggiore
# Processing Record 38 of Set 6 | barcelos
# Processing Record 39 of Set 6 | araouane
# Processing Record 40 of Set 6 | hay river
# Processing Record 41 of Set 6 | neiafu
# Processing Record 42 of Set 6 | nyurba
# Processing Record 43 of Set 6 | kushima
# Processing Record 44 of Set 6 | pavlovsk
# Processing Record 45 of Set 6 | bulungu
# Processing Record 46 of Set 6 | zedelgem
# Processing Record 47 of Set 6 | manzanillo
# Processing Record 48 of Set 6 | honningsvag
# Processing Record 49 of Set 6 | tasiilaq
# Processing Record 50 of Set 6 | vestmannaeyjar
# Processing Record 1 of Set 7 | najran
# Processing Record 2 of Set 7 | northam
# Processing Record 3 of Set 7 | orapa
# Processing Record 4 of Set 7 | eucaliptus
# Processing Record 5 of Set 7 | komsomolskiy
# Processing Record 6 of Set 7 | zhanaozen
# Processing Record 7 of Set 7 | saint augustine
# Processing Record 8 of Set 7 | samarai
# Processing Record 9 of Set 7 | lubao
# Processing Record 10 of Set 7 | goderich
# Processing Record 11 of Set 7 | tuatapere
# Processing Record 12 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 7 | nioro
# Processing Record 14 of Set 7 | andenes
# Processing Record 15 of Set 7 | farim
# Processing Record 16 of Set 7 | tha mai
# Processing Record 17 of Set 7 | shaowu
# Processing Record 18 of Set 7 | azuaga
# Processing Record 19 of Set 7 | maldonado
# Processing Record 20 of Set 7 | tura
# Processing Record 21 of Set 7 | bairiki
# Processing Record 22 of Set 7 | coahuayana
# Processing Record 23 of Set 7 | basco
# Processing Record 24 of Set 7 | kruisfontein
# Processing Record 25 of Set 7 | bayan
# Processing Record 26 of Set 7 | bandar-e lengeh
# Processing Record 27 of Set 7 | ulladulla
# Processing Record 28 of Set 7 | qinzhou
# Processing Record 29 of Set 7 | bukama
# Processing Record 30 of Set 7 | rapar
# Processing Record 31 of Set 7 | charlestown
# Processing Record 32 of Set 7 | camacupa
# Processing Record 33 of Set 7 | pilar
# Processing Record 34 of Set 7 | yellowknife
# Processing Record 35 of Set 7 | kyren
# Processing Record 36 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 7 | aksu
# Processing Record 38 of Set 7 | cabo san lucas
# Processing Record 39 of Set 7 | idritsa
# Processing Record 40 of Set 7 | ternate
# Processing Record 41 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 42 of Set 7 | virginia beach
# Processing Record 43 of Set 7 | maceio
# Processing Record 44 of Set 7 | marang
# Processing Record 45 of Set 7 | cansancao
# Processing Record 46 of Set 7 | lasa
# Processing Record 47 of Set 7 | chicama
# Processing Record 48 of Set 7 | ulaanbaatar
# Processing Record 49 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 7 | northview
# Processing Record 1 of Set 8 | saldanha
# Processing Record 2 of Set 8 | penzance
# Processing Record 3 of Set 8 | nikolskoye
# Processing Record 4 of Set 8 | prata
# Processing Record 5 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 6 of Set 8 | lima
# Processing Record 7 of Set 8 | pisco
# Processing Record 8 of Set 8 | ondjiva
# Processing Record 9 of Set 8 | swan hill
# Processing Record 10 of Set 8 | klaksvik
# Processing Record 11 of Set 8 | husavik
# Processing Record 12 of Set 8 | ambon
# Processing Record 13 of Set 8 | wanning
# Processing Record 14 of Set 8 | kushiro
# Processing Record 15 of Set 8 | alghero
# Processing Record 16 of Set 8 | dawlatabad
# Processing Record 17 of Set 8 | kazachinskoye
# Processing Record 18 of Set 8 | bartica
# Processing Record 19 of Set 8 | bodden town
# Processing Record 20 of Set 8 | balkhash
# Processing Record 21 of Set 8 | asyut
# Processing Record 22 of Set 8 | bria
# Processing Record 23 of Set 8 | winslow
# Processing Record 24 of Set 8 | yangcun
# Processing Record 25 of Set 8 | tiznit
# Processing Record 26 of Set 8 | yarada
# Processing Record 27 of Set 8 | mayor pablo lagerenza
# Processing Record 28 of Set 8 | faya
# Processing Record 29 of Set 8 | volchikha
# Processing Record 30 of Set 8 | lanzhou
# Processing Record 31 of Set 8 | flinders
# Processing Record 32 of Set 8 | olafsvik
# Processing Record 33 of Set 8 | manta
# Processing Record 34 of Set 8 | severo-kurilsk
# Processing Record 35 of Set 8 | chara
# Processing Record 36 of Set 8 | san vicente
# Processing Record 37 of Set 8 | kaduna
# Processing Record 38 of Set 8 | omsukchan
# Processing Record 39 of Set 8 | inhambane
# Processing Record 40 of Set 8 | havre-saint-pierre
# Processing Record 41 of Set 8 | amurzet
# Processing Record 42 of Set 8 | san patricio
# Processing Record 43 of Set 8 | olinda
# Processing Record 44 of Set 8 | shenzhen
# Processing Record 45 of Set 8 | padang
# Processing Record 46 of Set 8 | freeport
# Processing Record 47 of Set 8 | abu samrah
# Processing Record 48 of Set 8 | rawson
# Processing Record 49 of Set 8 | srednekolymsk
# Processing Record 50 of Set 8 | cidreira
# Processing Record 1 of Set 9 | el dorado
# Processing Record 2 of Set 9 | nome
# Processing Record 3 of Set 9 | sampit
# Processing Record 4 of Set 9 | belmonte
# Processing Record 5 of Set 9 | cortez
# Processing Record 6 of Set 9 | tonantins
# Processing Record 7 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 8 of Set 9 | santo antonio do ica
# Processing Record 9 of Set 9 | hami
# Processing Record 10 of Set 9 | imbituba
# Processing Record 11 of Set 9 | vostok
# Processing Record 12 of Set 9 | oktyabrskoye
# Processing Record 13 of Set 9 | harlingen
# Processing Record 14 of Set 9 | kasamwa
# Processing Record 15 of Set 9 | sheltozero
# Processing Record 16 of Set 9 | ahipara
# Processing Record 17 of Set 9 | bud
# Processing Record 18 of Set 9 | tsaratanana
# Processing Record 19 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 9 | beringovskiy
# Processing Record 21 of Set 9 | doha
# Processing Record 22 of Set 9 | masuri
# Processing Record 23 of Set 9 | batagay-alyta
# Processing Record 24 of Set 9 | salta
# Processing Record 25 of Set 9 | puerto berrio
# Processing Record 26 of Set 9 | puerto narino
# Processing Record 27 of Set 9 | bay roberts
# Processing Record 28 of Set 9 | tautira
# Processing Record 29 of Set 9 | sorland
# Processing Record 30 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 9 | rochelle
# Processing Record 32 of Set 9 | hervey bay
# Processing Record 33 of Set 9 | kang
# Processing Record 34 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 9 | valer
# Processing Record 36 of Set 9 | revda
# Processing Record 37 of Set 9 | syamzha
# Processing Record 38 of Set 9 | hearst
# Processing Record 39 of Set 9 | klyuchi
# Processing Record 40 of Set 9 | saint anthony
# Processing Record 41 of Set 9 | chernoyerkovskaya
# Processing Record 42 of Set 9 | lurate caccivio
# Processing Record 43 of Set 9 | bantacan
# Processing Record 44 of Set 9 | kijang
# Processing Record 45 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 46 of Set 9 | nishihara
# Processing Record 47 of Set 9 | jiexiu
# Processing Record 48 of Set 9 | berlevag
# Processing Record 49 of Set 9 | uige
# Processing Record 50 of Set 9 | susanville
# Processing Record 1 of Set 10 | yamoussoukro
# Processing Record 2 of Set 10 | eenhana
# Processing Record 3 of Set 10 | pangnirtung
# Processing Record 4 of Set 10 | filimonovo
# Processing Record 5 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 10 | mandalgovi
# Processing Record 7 of Set 10 | okha
# Processing Record 8 of Set 10 | mirnyy
# Processing Record 9 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 10 | moron
# Processing Record 11 of Set 10 | belaya gora
# Processing Record 12 of Set 10 | adre
# Processing Record 13 of Set 10 | yulara
# Processing Record 14 of Set 10 | rio brilhante
# Processing Record 15 of Set 10 | renqiu
# Processing Record 16 of Set 10 | asau
# Processing Record 17 of Set 10 | urumqi
# Processing Record 18 of Set 10 | qom
# Processing Record 19 of Set 10 | vierzon
# Processing Record 20 of Set 10 | taft
# Processing Record 21 of Set 10 | naze
# Processing Record 22 of Set 10 | praya
# Processing Record 23 of Set 10 | ranfurly
# Processing Record 24 of Set 10 | auki
# Processing Record 25 of Set 10 | colorado springs
# Processing Record 26 of Set 10 | quatre cocos
# Processing Record 27 of Set 10 | adet
# Processing Record 28 of Set 10 | burns lake
# Processing Record 29 of Set 10 | kalamakion
# City not found. Skipping...
# Processing Record 30 of Set 10 | meulaboh
# Processing Record 31 of Set 10 | aksarka
# Processing Record 32 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 10 | port hardy
# Processing Record 34 of Set 10 | cody
# Processing Record 35 of Set 10 | sassandra
# Processing Record 36 of Set 10 | nanakuli
# Processing Record 37 of Set 10 | plettenberg bay
# Processing Record 38 of Set 10 | noumea
# Processing Record 39 of Set 10 | porto belo
# Processing Record 40 of Set 10 | buraydah
# Processing Record 41 of Set 10 | lompoc
# Processing Record 42 of Set 10 | estelle
# Processing Record 43 of Set 10 | zaraza
# Processing Record 44 of Set 10 | ban nahin
# Processing Record 45 of Set 10 | passo de camaragibe
# Processing Record 46 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 10 | mirina
# City not found. Skipping...
# Processing Record 48 of Set 10 | tabas
# Processing Record 49 of Set 10 | hommelvik
# Processing Record 50 of Set 10 | linshui
# Processing Record 1 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 11 | necochea
# Processing Record 3 of Set 11 | sandpoint
# Processing Record 4 of Set 11 | la rioja
# Processing Record 5 of Set 11 | cherskiy
# Processing Record 6 of Set 11 | rantepao
# Processing Record 7 of Set 11 | gasa
# Processing Record 8 of Set 11 | geraldton
# Processing Record 9 of Set 11 | kabanjahe
# Processing Record 10 of Set 11 | nuevitas
# Processing Record 11 of Set 11 | porto franco
# Processing Record 12 of Set 11 | salym
# Processing Record 13 of Set 11 | burica
# City not found. Skipping...
# Processing Record 14 of Set 11 | talakan
# Processing Record 15 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 16 of Set 11 | whitehorse
# Processing Record 17 of Set 11 | mercedes
# Processing Record 18 of Set 11 | port-gentil
# Processing Record 19 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 11 | vagay
# Processing Record 21 of Set 11 | bolshoye selo
# Processing Record 22 of Set 11 | yuncheng
# Processing Record 23 of Set 11 | fort abbas
# Processing Record 24 of Set 11 | bhikangaon
# Processing Record 25 of Set 11 | obo
# Processing Record 26 of Set 11 | leningradskiy
# Processing Record 27 of Set 11 | kushmurun
# Processing Record 28 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 11 | santa rosalia
# Processing Record 30 of Set 11 | ponta delgada
# Processing Record 31 of Set 11 | yurimaguas
# Processing Record 32 of Set 11 | kodinsk
# Processing Record 33 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 34 of Set 11 | mineiros
# Processing Record 35 of Set 11 | kobayashi
# Processing Record 36 of Set 11 | yenagoa
# Processing Record 37 of Set 11 | riyadh
# Processing Record 38 of Set 11 | dossor
# Processing Record 39 of Set 11 | chanika
# Processing Record 40 of Set 11 | kajaani
# Processing Record 41 of Set 11 | aquiraz
# Processing Record 42 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 11 | kapuskasing
# Processing Record 44 of Set 11 | constitucion
# Processing Record 45 of Set 11 | kudahuvadhoo
# Processing Record 46 of Set 11 | san pedro de ycuamandiyu
# Processing Record 47 of Set 11 | nuuk
# Processing Record 48 of Set 11 | marienburg
# Processing Record 49 of Set 11 | moerai
# Processing Record 50 of Set 11 | qaqortoq
# Processing Record 1 of Set 12 | severobaykalsk
# Processing Record 2 of Set 12 | nemuro
# Processing Record 3 of Set 12 | morondava
# Processing Record 4 of Set 12 | muravlenko
# Processing Record 5 of Set 12 | gosainganj
# Processing Record 6 of Set 12 | hambantota
# Processing Record 7 of Set 12 | presidente dutra
# Processing Record 8 of Set 12 | abapo
# Processing Record 9 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 12 | salmas
# Processing Record 11 of Set 12 | inongo
# Processing Record 12 of Set 12 | waipawa
# Processing Record 13 of Set 12 | pucallpa
# Processing Record 14 of Set 12 | florianopolis
# Processing Record 15 of Set 12 | cessnock
# Processing Record 16 of Set 12 | bandarbeyla
# Processing Record 17 of Set 12 | peniche
# Processing Record 18 of Set 12 | algeciras
# Processing Record 19 of Set 12 | tomatlan
# Processing Record 20 of Set 12 | kyakhta
# Processing Record 21 of Set 12 | french harbor
# Processing Record 22 of Set 12 | carnot
# Processing Record 23 of Set 12 | cacu
# Processing Record 24 of Set 12 | sosnovo-ozerskoye
# Processing Record 25 of Set 12 | oskaloosa
# Processing Record 26 of Set 12 | nouadhibou
# Processing Record 27 of Set 12 | honiara
# Processing Record 28 of Set 12 | slatina
# Processing Record 29 of Set 12 | kashary
# Processing Record 30 of Set 12 | sao raimundo nonato
# Processing Record 31 of Set 12 | tual
# Processing Record 32 of Set 12 | kuching
# Processing Record 33 of Set 12 | erenhot
# Processing Record 34 of Set 12 | lesosibirsk
# Processing Record 35 of Set 12 | presidencia roque saenz pena
# Processing Record 36 of Set 12 | chumikan
# Processing Record 37 of Set 12 | codrington
# Processing Record 38 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 12 | behshahr
# Processing Record 40 of Set 12 | zyryanovsk
# Processing Record 41 of Set 12 | jiaozhou
# Processing Record 42 of Set 12 | lhokseumawe
# Processing Record 43 of Set 12 | dunedin
# Processing Record 44 of Set 12 | okhotsk
# Processing Record 45 of Set 12 | sungaipenuh
# Processing Record 46 of Set 12 | seinajoki
# Processing Record 47 of Set 12 | camacari
# Processing Record 48 of Set 12 | koupela
# Processing Record 49 of Set 12 | havoysund
# Processing Record 50 of Set 12 | amparai
# City not found. Skipping...
# Processing Record 1 of Set 13 | terme
# Processing Record 2 of Set 13 | matagami
# Processing Record 3 of Set 13 | baykit
# Processing Record 4 of Set 13 | cap malheureux
# Processing Record 5 of Set 13 | wamba
# Processing Record 6 of Set 13 | sabang
# Processing Record 7 of Set 13 | umm ruwabah
# City not found. Skipping...
# Processing Record 8 of Set 13 | sakakah
# Processing Record 9 of Set 13 | mount pleasant
# Processing Record 10 of Set 13 | grindavik
# Processing Record 11 of Set 13 | hot springs
# Processing Record 12 of Set 13 | roald
# Processing Record 13 of Set 13 | guaimaca
# Processing Record 14 of Set 13 | zhaotong
# Processing Record 15 of Set 13 | chegdomyn
# Processing Record 16 of Set 13 | gamba
# Processing Record 17 of Set 13 | mormugao
# Processing Record 18 of Set 13 | antofagasta
# Processing Record 19 of Set 13 | bafoulabe
# Processing Record 20 of Set 13 | darnah
# Processing Record 21 of Set 13 | dingle
# Processing Record 22 of Set 13 | kosh-agach
# Processing Record 23 of Set 13 | zarate
# Processing Record 24 of Set 13 | beaupre
# Processing Record 25 of Set 13 | pinar del rio
# Processing Record 26 of Set 13 | sidi ali
# Processing Record 27 of Set 13 | anadyr
# Processing Record 28 of Set 13 | ananas
# Processing Record 29 of Set 13 | agucadoura
# Processing Record 30 of Set 13 | acuna
# City not found. Skipping...
# Processing Record 31 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 32 of Set 13 | detva
# Processing Record 33 of Set 13 | ossora
# Processing Record 34 of Set 13 | ondangwa
# Processing Record 35 of Set 13 | kampot
# Processing Record 36 of Set 13 | menongue
# Processing Record 37 of Set 13 | kaa-khem
# Processing Record 38 of Set 13 | kirovskiy
# Processing Record 39 of Set 13 | venado tuerto
# Processing Record 40 of Set 13 | gannan
# Processing Record 41 of Set 13 | port lincoln
# Processing Record 42 of Set 13 | pontianak
# Processing Record 43 of Set 13 | rio gallegos
# Processing Record 44 of Set 13 | akdepe
# Processing Record 45 of Set 13 | hauge
# Processing Record 46 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 13 | lorengau
# Processing Record 48 of Set 13 | beloha
# Processing Record 49 of Set 13 | tutoia
# Processing Record 50 of Set 13 | lac du bonnet
# Processing Record 1 of Set 14 | mastic beach
# Processing Record 2 of Set 14 | neuquen
# Processing Record 3 of Set 14 | old orchard beach
# Processing Record 4 of Set 14 | acapulco
# Processing Record 5 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 14 | nakambala
# Processing Record 7 of Set 14 | sao felix do xingu
# Processing Record 8 of Set 14 | north bend
# Processing Record 9 of Set 14 | chimoio
# Processing Record 10 of Set 14 | ayorou
# Processing Record 11 of Set 14 | sept-iles
# Processing Record 12 of Set 14 | hualmay
# Processing Record 13 of Set 14 | maarianhamina
# Processing Record 14 of Set 14 | edenderry
# Processing Record 15 of Set 14 | tchaourou
# Processing Record 16 of Set 14 | yugo-kamskiy
# Processing Record 17 of Set 14 | malanje
# Processing Record 18 of Set 14 | si satchanalai
# Processing Record 19 of Set 14 | safaga
# Processing Record 20 of Set 14 | biak
# Processing Record 21 of Set 14 | yuli
# Processing Record 22 of Set 14 | zhetybay
# City not found. Skipping...
# Processing Record 23 of Set 14 | coffeyville
# Processing Record 24 of Set 14 | novosergiyevka
# Processing Record 25 of Set 14 | itaqui
# Processing Record 26 of Set 14 | siuna
# Processing Record 27 of Set 14 | mayo
# Processing Record 28 of Set 14 | prince albert
# Processing Record 29 of Set 14 | bauchi
# Processing Record 30 of Set 14 | daxian
# City not found. Skipping...
# Processing Record 31 of Set 14 | praia
# Processing Record 32 of Set 14 | mirpur sakro
# Processing Record 33 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 14 | flin flon
# Processing Record 35 of Set 14 | karaman
# Processing Record 36 of Set 14 | nakhon thai
# Processing Record 37 of Set 14 | maghar
# Processing Record 38 of Set 14 | concordia
# Processing Record 39 of Set 14 | gravdal
# Processing Record 40 of Set 14 | caravelas
# Processing Record 41 of Set 14 | acajutla
# Processing Record 42 of Set 14 | gobabis
# Processing Record 43 of Set 14 | surt
# Processing Record 44 of Set 14 | lobatse
# Processing Record 45 of Set 14 | blackwater
# Processing Record 46 of Set 14 | palu
# Processing Record 47 of Set 14 | granger
# Processing Record 48 of Set 14 | faranah
# Processing Record 49 of Set 14 | burnie
# Processing Record 50 of Set 14 | ostrovnoy
# Processing Record 1 of Set 15 | belyy yar
# Processing Record 2 of Set 15 | taltal
# Processing Record 3 of Set 15 | chicomuselo
# Processing Record 4 of Set 15 | ikalamavony
# Processing Record 5 of Set 15 | san lorenzo
# Processing Record 6 of Set 15 | ishigaki
# Processing Record 7 of Set 15 | metro
# Processing Record 8 of Set 15 | ust-nera
# Processing Record 9 of Set 15 | naron
# Processing Record 10 of Set 15 | priiskovyy
# Processing Record 11 of Set 15 | namatanai
# Processing Record 12 of Set 15 | puerto madryn
# Processing Record 13 of Set 15 | karratha
# Processing Record 14 of Set 15 | salinopolis
# Processing Record 15 of Set 15 | marquette
# Processing Record 16 of Set 15 | jobat
# Processing Record 17 of Set 15 | chinhoyi
# Processing Record 18 of Set 15 | mana
# Processing Record 19 of Set 15 | bijie
# Processing Record 20 of Set 15 | igarka
# Processing Record 21 of Set 15 | prince rupert
# Processing Record 22 of Set 15 | umm kaddadah
# Processing Record 23 of Set 15 | portland
# Processing Record 24 of Set 15 | saint-francois
# Processing Record 25 of Set 15 | khromtau
# Processing Record 26 of Set 15 | blind river
# Processing Record 27 of Set 15 | ucluelet
# Processing Record 28 of Set 15 | christchurch
# Processing Record 29 of Set 15 | xifeng
# Processing Record 30 of Set 15 | te anau
# Processing Record 31 of Set 15 | bataipora
# Processing Record 32 of Set 15 | kenai
# Processing Record 33 of Set 15 | urusha
# Processing Record 34 of Set 15 | dibulla
# Processing Record 35 of Set 15 | alofi
# Processing Record 36 of Set 15 | wajima
# Processing Record 37 of Set 15 | katherine
# Processing Record 38 of Set 15 | metapan
# Processing Record 39 of Set 15 | labuhan
# Processing Record 40 of Set 15 | ilhabela
# Processing Record 41 of Set 15 | kavaratti
# Processing Record 42 of Set 15 | pundaguitan
# Processing Record 43 of Set 15 | barcelona
# Processing Record 44 of Set 15 | takab
# Processing Record 45 of Set 15 | rio grande
# Processing Record 46 of Set 15 | tabuk
# Processing Record 47 of Set 15 | havre
# Processing Record 48 of Set 15 | galle
# Processing Record 49 of Set 15 | zemio
# Processing Record 50 of Set 15 | maniwaki
# Processing Record 1 of Set 16 | sri aman
# Processing Record 2 of Set 16 | loukhi
# Processing Record 3 of Set 16 | portmore
# Processing Record 4 of Set 16 | huarmey
# Processing Record 5 of Set 16 | sao joao da barra
# Processing Record 6 of Set 16 | rauma
# Processing Record 7 of Set 16 | sataua
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Upernavik  72.7868  -56.1549     10.98        86          58
# 1        Rikitea -23.1203 -134.9692     78.91        75          19
# 2          Bluff -46.6000  168.3333     60.01        56          69
# 3       Katsuura  35.1333  140.3000     39.00        69          95
# 4  Leshukonskoye  64.8989   45.7622     -7.11        91          92
# 5     Port Keats -14.2500  129.5500     80.46        79          57
# 6         Lashio  22.9333   97.7500     50.23        91          84
# 7   Jacareacanga  -6.2222  -57.7528     77.09        94         100
# 8       Souillac -20.5167   57.5167     78.80        78          75
# 9           Kaeo -35.1000  173.7833     73.00        57          15
#
#    Wind Speed      Description Country                 Date
# 0        7.87    broken clouds      GL  2021-01-17 22:24:27
# 1       14.74       few clouds      PF  2021-01-17 22:24:27
# 2        8.01    broken clouds      NZ  2021-01-17 22:24:27
# 3        4.00  overcast clouds      JP  2021-01-17 22:24:27
# 4        3.44  overcast clouds      RU  2021-01-17 22:24:27
# 5        6.22    broken clouds      AU  2021-01-17 22:24:27
# 6        1.05    broken clouds      MM  2021-01-17 22:24:27
# 7        1.95  overcast clouds      BR  2021-01-17 22:24:27
# 8       11.50    broken clouds      MU  2021-01-17 22:20:26
# 9       10.00       few clouds      NZ  2021-01-17 22:24:27

# %%
city_data_df.to_csv('Weather_Database\WeatherPy_Database.csv', index = False)
